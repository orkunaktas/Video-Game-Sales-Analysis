# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("datasets/vgsales.csv") # index_col=0 index siler
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df.shape
# Out:
# (16598, 11)

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df[df["Publisher"].isnull()]  #eksik veriler geldi
# Out:
# Empty DataFrame
# Columns: [Rank, Name, Platform, Year, Genre, Publisher, NA_Sales, EU_Sales, JP_Sales, Other_Sales, Global_Sales]
# Index: []

# %%
df.dropna(inplace=True)

# %%
df.isnull().sum()
# Out:
# Rank            0
# Name            0
# Platform        0
# Year            0
# Genre           0
# Publisher       0
# NA_Sales        0
# EU_Sales        0
# JP_Sales        0
# Other_Sales     0
# Global_Sales    0
# dtype: int64

# %%
df[(df["Genre"] == "Sports") & (df["Publisher"] == "Take-Two Interactive") & (df["Global_Sales"] >= 2 )]
# Out:
#      Rank      Name Platform    Year   Genre             Publisher  NA_Sales  \
# 314   315  NBA 2K16      PS4  2015.0  Sports  Take-Two Interactive      2.48
# 468   469  NBA 2K13     X360  2012.0  Sports  Take-Two Interactive      2.60
# 584   585  NBA 2K12     X360  2011.0  Sports  Take-Two Interactive      2.31
# 623   624  NBA 2K13      PS3  2012.0  Sports  Take-Two Interactive      1.72
# 625   626  NBA 2K14     X360  2013.0  Sports  Take-Two Interactive      2.10
# 661   663  NBA 2K15      PS4  2014.0  Sports  Take-Two Interactive      1.46
# 681   683  NBA 2K16     XOne  2015.0  Sports  Take-Two Interactive      1.93
# 776   778  NBA 2K12      PS3  2011.0  Sports  Take-Two Interactive      1.61
# 823   825  NBA 2K14      PS3  2013.0  Sports  Take-Two Interactive      1.43
#
#      EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 314      0.65      0.03         0.69          3.85
# 468      0.21      0.01         0.19          3.00
# ...

# %%
p = df.groupby("Genre")["Global_Sales"].mean().reset_index()
p
# Out:
#            Genre  Global_Sales
# 0         Action      0.529942
# 1      Adventure      0.184137
# 2       Fighting      0.531160
# 3           Misc      0.468488
# 4       Platform      0.947577
# 5         Puzzle      0.424930
# 6         Racing      0.593273
# 7   Role-Playing      0.628456
# 8        Shooter      0.800468
# 9     Simulation      0.459882
# 10        Sports      0.568247
# 11      Strategy      0.258612

# %%
df[(df["Publisher"] == "Electronic Arts") & (df["Global_Sales"] >= 6)]  #Publisher = EA
# Out:
#      Rank                          Name Platform    Year       Genre  \
# 77     78                       FIFA 16      PS4  2015.0      Sports
# 82     83                FIFA Soccer 13      PS3  2012.0      Action
# 83     84                    The Sims 3       PC  2009.0  Simulation
# 92     93  Star Wars Battlefront (2015)      PS4  2015.0     Shooter
# 99    100                 Battlefield 3     X360  2011.0     Shooter
# 103   104                 Battlefield 3      PS3  2011.0     Shooter
# 104   105    Need for Speed Underground      PS2  2003.0      Racing
# 112   113                       FIFA 14      PS3  2013.0      Sports
# 113   114  Need for Speed Underground 2      PS2  2004.0      Racing
# 114   115     Medal of Honor: Frontline      PS2  2002.0     Shooter
# 121   122                       FIFA 12      PS3  2011.0      Sports
# 124   125                       FIFA 15      PS4  2014.0      Sports
#
# ...

# %%
df[(df["Publisher"] == "Ubisoft")].head(4)
# Out:
#      Rank          Name Platform    Year Genre Publisher  NA_Sales  EU_Sales  \
# 60     61  Just Dance 3      Wii  2011.0  Misc   Ubisoft      6.05      3.15
# 68     69  Just Dance 2      Wii  2010.0  Misc   Ubisoft      5.84      2.89
# 102   103    Just Dance      Wii  2009.0  Misc   Ubisoft      3.51      3.03
# 111   112  Just Dance 4      Wii  2012.0  Misc   Ubisoft      4.14      2.21
#
#      JP_Sales  Other_Sales  Global_Sales
# 60       0.00         1.07         10.26
# 68       0.01         0.78          9.52
# 102      0.00         0.73          7.27
# 111      0.00         0.56          6.91

# %%
df["Publisher"].value_counts().reset_index().head(20)
# Out:
#                                      index  Publisher
# 0                          Electronic Arts       1339
# 1                               Activision        966
# 2                       Namco Bandai Games        928
# 3                                  Ubisoft        918
# 4             Konami Digital Entertainment        823
# 5                                      THQ        712
# 6                                 Nintendo        696
# 7              Sony Computer Entertainment        682
# 8                                     Sega        632
# 9                     Take-Two Interactive        412
# 10                                  Capcom        376
# 11                                   Atari        347
# 12                              Tecmo Koei        338
# 13                             Square Enix        231
# 14  Warner Bros. Interactive Entertainment        217
# 15              Disney Interactive Studios        214
# ...

# %%
df.nunique() #Sütunların içinde kaç farklı değer var
# Out:
# Rank            16291
# Name            11325
# Platform           31
# Year               39
# Genre              12
# Publisher         576
# NA_Sales          408
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      621
# dtype: int64

# %%
df.columns
# Out:
# Index(['Rank', 'Name', 'Platform', 'Year', 'Genre', 'Publisher', 'NA_Sales',
#        'EU_Sales', 'JP_Sales', 'Other_Sales', 'Global_Sales'],
#       dtype='object')

# %%
df["Genre"].unique() #Kaç farklı tür çeşidi var?
# Out:
# array(['Sports', 'Platform', 'Racing', 'Role-Playing', 'Puzzle', 'Misc',
#        'Shooter', 'Simulation', 'Action', 'Fighting', 'Adventure',
#        'Strategy'], dtype=object)

# %%
df.groupby("Genre")["Other_Sales"].count() #Türlerden kaçar adet var?
# Out:
# Genre
# Action          3251
# Adventure       1274
# Fighting         836
# Misc            1686
# Platform         875
# Puzzle           570
# Racing          1225
# Role-Playing    1470
# Shooter         1282
# Simulation       848
# Sports          2304
# Strategy         670
# Name: Other_Sales, dtype: int64

# %%
df["Year"].count()  #kaç adet Year sütunu var?
# Out:
# 16291

# %%
df["Genre"].value_counts() #Türlerden kaçar adet var?
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
df.describe().T
# Out:
#                 count         mean          std      min      25%      50%  \
# Rank          16291.0  8290.190228  4792.654450     1.00  4132.50  8292.00
# Year          16291.0  2006.405561     5.832412  1980.00  2003.00  2007.00
# NA_Sales      16291.0     0.265647     0.822432     0.00     0.00     0.08
# EU_Sales      16291.0     0.147731     0.509303     0.00     0.00     0.02
# JP_Sales      16291.0     0.078833     0.311879     0.00     0.00     0.00
# Other_Sales   16291.0     0.048426     0.190083     0.00     0.00     0.01
# Global_Sales  16291.0     0.540910     1.567345     0.01     0.06     0.17
#
#                    75%       max
# Rank          12439.50  16600.00
# Year           2010.00   2020.00
# NA_Sales          0.24     41.49
# EU_Sales          0.11     29.02
# JP_Sales          0.04     10.22
# Other_Sales       0.04     10.57
# Global_Sales      0.48     82.74

# %%
sns.countplot(x="Genre",data=df, palette="bright")
plt.xlabel("Grade")
plt.ylabel("Adet")
plt.xticks(fontsize=9,rotation=45)
plt.title("Oyun Türleri ve Adetleri")
plt.show()

# %%
df[["Global_Sales"]].head(10)  #frame halinde görmek için 2 parantez
# Out:
#    Global_Sales
# 0         82.74
# 1         40.24
# 2         35.82
# 3         33.00
# 4         31.37
# 5         30.26
# 6         30.01
# 7         29.02
# 8         28.62
# 9         28.31

# %%
df["Global_Sales"].reset_index().head(10)  #frame halinde görüp index eklemek için reset index
# Out:
#    index  Global_Sales
# 0      0         82.74
# 1      1         40.24
# 2      2         35.82
# 3      3         33.00
# 4      4         31.37
# 5      5         30.26
# 6      6         30.01
# 7      7         29.02
# 8      8         28.62
# 9      9         28.31

# %%
year_df = df.groupby("Year").sum()
year_df = year_df[["Global_Sales"]]
year_df.tail() # yıllara göre global sales toplamları
# Out:
# C:\Users\orkun\AppData\Local\Temp\ipykernel_6024\2398631938.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_df = df.groupby("Year").sum()
#         Global_Sales
# Year
# 2014.0        337.03
# 2015.0        264.44
# 2016.0         70.90
# 2017.0          0.05
# 2020.0          0.29

# %%
customer = df.groupby("Year").sum().sort_values("Global_Sales",ascending=False)
customer.drop(["Rank","NA_Sales","EU_Sales","JP_Sales","Other_Sales"],axis=1,inplace=True) # burası gereksiz sütunları siler
customer.head(5) #Global Sales en yüksekten en düşüğe
# Out:
# C:\Users\orkun\AppData\Local\Temp\ipykernel_6024\3960309485.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   customer = df.groupby("Year").sum().sort_values("Global_Sales",ascending=False)
#         Global_Sales
# Year
# 2008.0        678.90
# 2009.0        667.30
# 2007.0        609.92
# 2010.0        600.29
# 2006.0        521.04

# %%
customer.reset_index(inplace=True)
customer.head(6)
# Out:
#      Year  Global_Sales
# 0  2008.0        678.90
# 1  2009.0        667.30
# 2  2007.0        609.92
# 3  2010.0        600.29
# 4  2006.0        521.04
# 5  2011.0        515.80

# %%
plt.figure(figsize=(10, 6))
colors = sns.color_palette("RdYlGn", len(df["Year"].unique()))
plt.bar(customer["Year"],customer["Global_Sales"], color=colors)
plt.title("Yıllara göre global oyun satışı miktarları (milyon) ")
plt.xticks(fontsize=10, rotation=0)
plt.yticks(fontsize=12)
plt.xlabel("Yıl")
plt.ylabel("Satış Miktarı (milyon)")
plt.show()

# %%
df.nunique()
# Out:
# Rank            16291
# Name            11325
# Platform           31
# Year               39
# Genre              12
# Publisher         576
# NA_Sales          408
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      621
# dtype: int64

# %%
category = df.groupby("Genre").sum().sort_values("Global_Sales",ascending=False)
category.drop(["Rank","NA_Sales","EU_Sales","JP_Sales","Other_Sales","Year"],axis=1,inplace=True) # burası gereksiz sütunları siler
category.head(5) #Global Sales en yüksekten en düşüğe
# Out:
# C:\Users\orkun\AppData\Local\Temp\ipykernel_6024\469426538.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   category = df.groupby("Genre").sum().sort_values("Global_Sales",ascending=False)
#               Global_Sales
# Genre
# Action             1722.84
# Sports             1309.24
# Shooter            1026.20
# Role-Playing        923.83
# Platform            829.13

# %%
category.reset_index(inplace=True)
category.head(6)
# Out:
#           Genre  Global_Sales
# 0        Action       1722.84
# 1        Sports       1309.24
# 2       Shooter       1026.20
# 3  Role-Playing        923.83
# 4      Platform        829.13
# 5          Misc        789.87

# %%
plt.figure(figsize=(10, 6))
colors = sns.color_palette("RdYlGn", len(df["Genre"].unique()))
plt.bar(category["Genre"],category["Global_Sales"], color=colors)
plt.title("Oyun türlerine göre global oyun satışı miktarları (milyon)")
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.xlabel("Oyun türü")
plt.ylabel("Satış Miktarı (milyon)")
plt.show()

# %%
category = df.groupby("Genre").sum().sort_values("EU_Sales",ascending=False)
category.drop(["Rank","NA_Sales","Global_Sales","JP_Sales","Other_Sales","Year"],axis=1,inplace=True) # burası gereksiz sütunları siler
category.head(5) #Europe Sales en yüksekten en düşüğe
# Out:
# C:\Users\orkun\AppData\Local\Temp\ipykernel_6024\260951100.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   category = df.groupby("Genre").sum().sort_values("EU_Sales",ascending=False)
#          EU_Sales
# Genre
# Action     516.48
# Sports     371.34
# Shooter    310.45
# Racing     236.31
# Misc       211.77

# %%
category.reset_index(inplace=True)
category.head(6)
# Out:
#       Genre  EU_Sales
# 0    Action    516.48
# 1    Sports    371.34
# 2   Shooter    310.45
# 3    Racing    236.31
# 4      Misc    211.77
# 5  Platform    200.65

# %%
plt.figure(figsize=(10, 6))
colors = sns.color_palette("RdYlGn", len(df["Genre"].unique()))
plt.bar(category["Genre"],category["EU_Sales"], color=colors)
plt.title("Oyun türlerine göre avrupada oyun satışı miktarları (milyon)")
plt.xticks(fontsize=10, rotation=45)
plt.yticks(fontsize=12)
plt.xlabel("Oyun türü")
plt.ylabel("Avrupa Satış Miktarı (milyon)")
plt.show()

# %%
year_eu = df.groupby("Year").sum().sort_values("EU_Sales",ascending=False)
year_eu.drop(["Rank","NA_Sales","Global_Sales","JP_Sales","Other_Sales"],axis=1,inplace=True) # burası gereksiz sütunları siler
year_eu.head(5) #Yıl ve avrupa satış toplamlarını verdi
# Out:
# C:\Users\orkun\AppData\Local\Temp\ipykernel_6024\1741551892.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   year_eu = df.groupby("Year").sum().sort_values("EU_Sales",ascending=False)
#         EU_Sales
# Year
# 2009.0    191.59
# 2008.0    184.40
# 2010.0    176.57
# 2011.0    167.31
# 2007.0    160.18

# %%
year_eu.reset_index(inplace=True)
year_eu.head(6)
# Out:
#      Year  EU_Sales
# 0  2009.0    191.59
# 1  2008.0    184.40
# 2  2010.0    176.57
# 3  2011.0    167.31
# 4  2007.0    160.18
# 5  2006.0    129.24

# %%
plt.figure(figsize=(10, 6))
colors = sns.color_palette("RdYlGn", len(df["Year"].unique()))
plt.bar(year_eu["Year"],year_eu["EU_Sales"], color=colors)
plt.title("Yıllara göre avrupada oyun satışı miktarları (milyon) ")
plt.xticks(fontsize=10, rotation=0)
plt.yticks(fontsize=12)
plt.xlabel("Yıl")
plt.ylabel("Satış Miktarı (milyon)")
plt.show()

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
eu_satis = df["EU_Sales"].sum()
eu_satis
jp_satis = df["JP_Sales"].sum().round(2)
jp_satis
na_satis = df["NA_Sales"].sum().round(2)
na_satis
print("Avrupa toplam satış:", eu_satis)
print("Japonya toplam satış:", jp_satis)
print("Amerika toplam satış:", na_satis)
# Out:
# Avrupa toplam satış: 2406.69
# Japonya toplam satış: 1284.27
# Amerika toplam satış: 4327.65

# %%
toplam = {
     "Satislar": [eu_satis,jp_satis,na_satis],
     "Bolge": ["Avrupa","Japonya","Amerika"],
}

# %%
toplams.dtypes
# Out:
# Satislar    float64
# Bolge        object
# dtype: object

# %%
toplams.Bolge = pd.Categorical(toplams.Bolge)   #object den category'ye çevirdik 

# "category" türü, benzersiz değerleri bir kategori tablosunda saklayarak, her bir benzersiz değere bir kategori kodu atar.
#Bu, tekrarlanan değerlerin aynı kategori kodunu paylaşması anlamına gelir ve bellek kullanımını azaltır.

# %%
toplams.dtypes
# Out:
# Satislar     float64
# Bolge       category
# dtype: object

# %%
toplams = pd.DataFrame(toplam)
toplams
# Out:
#    Satislar    Bolge
# 0   2406.69   Avrupa
# 1   1284.27  Japonya
# 2   4327.65  Amerika

# %%
plt.bar(toplams["Bolge"], toplams["Satislar"],color=["Blue","Green","Red"])
plt.title("Bölgelere göre oyun satış rakamları")
plt.xlabel("Bölge")
plt.ylabel("Satış Miktarı")
plt.show()

# %%
plt.figure(figsize=(6, 4))
plt.plot(toplams['Bolge'], toplams['Satislar'], color="blue") #plt.bar -- plt.scatter 
plt.title("Yaşlara Göre Maaş")
plt.xlabel('Yaş')
plt.ylabel('Maaş')
plt.show()

# %%
xpoints = np.array(["Avrupa","Japonya","Amerika"])
ypoints = np.array([2406.69, 1284.27, 4327.65])
plt.plot(xpoints, ypoints)  #plt.stem
plt.show()

# %%
df.dtypes
# Out:
# Rank              int64
# Name             object
# Platform         object
# Year            float64
# Genre            object
# Publisher        object
# NA_Sales        float64
# EU_Sales        float64
# JP_Sales        float64
# Other_Sales     float64
# Global_Sales    float64
# dtype: object

# %%
#Çağırmak istediğimiz sütunun türünü categoryye çeviripde çağırabiliriz

# %%
kat_df = df.select_dtypes(include = ["Float64"])
kat_df.head()  #float64 türündeki sütunları çağırma
# Out:
#      Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0  2006.0     41.49     29.02      3.77         8.46         82.74
# 1  1985.0     29.08      3.58      6.81         0.77         40.24
# 2  2008.0     15.85     12.88      3.79         3.31         35.82
# 3  2009.0     15.75     11.01      3.28         2.96         33.00
# 4  1996.0     11.27      8.89     10.22         1.00         31.37

# %%
kat_df.drop(["Year","NA_Sales","EU_Sales","Other_Sales","JP_Sales"],axis=1,inplace=True)
kat_df.head()   #istemediğimiz sütunları sildik
# Out:
#    Global_Sales
# 0         82.74
# 1         40.24
# 2         35.82
# 3         33.00
# 4         31.37

# %%
cpy_df = df.copy()
cpy_df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
cpy_df.drop(["Year","Platform","Genre","NA_Sales","EU_Sales","JP_Sales","Other_Sales"],axis=1,inplace=True)
cpy_df.head()    #istemediğimiz sütunları sildik
# Out:
#    Rank                      Name Publisher  Global_Sales
# 0     1                Wii Sports  Nintendo         82.74
# 1     2         Super Mario Bros.  Nintendo         40.24
# 2     3            Mario Kart Wii  Nintendo         35.82
# 3     4         Wii Sports Resort  Nintendo         33.00
# 4     5  Pokemon Red/Pokemon Blue  Nintendo         31.37

# %%
cpy_df[["Rank", "Name", "Publisher", "Global_Sales"]].head() #böyle yaparak belirli sütunları çağırabiliriz
# Out:
#    Rank                      Name Publisher  Global_Sales
# 0     1                Wii Sports  Nintendo         82.74
# 1     2         Super Mario Bros.  Nintendo         40.24
# 2     3            Mario Kart Wii  Nintendo         35.82
# 3     4         Wii Sports Resort  Nintendo         33.00
# 4     5  Pokemon Red/Pokemon Blue  Nintendo         31.37

# %%
df.nunique()
# Out:
# Rank            16291
# Name            11325
# Platform           31
# Year               39
# Genre              12
# Publisher         576
# NA_Sales          408
# EU_Sales          305
# JP_Sales          244
# Other_Sales       157
# Global_Sales      621
# dtype: int64

# %%
df["Genre"].value_counts()
# Out:
# Action          3251
# Sports          2304
# Misc            1686
# Role-Playing    1470
# Shooter         1282
# Adventure       1274
# Racing          1225
# Platform         875
# Simulation       848
# Fighting         836
# Strategy         670
# Puzzle           570
# Name: Genre, dtype: int64

# %%
df["Genre"].value_counts().plot.barh().set_title("Türlerin adetleri");

# %%
sns.catplot(x = "Genre", y = "Global_Sales", data = df)
plt.ylabel("Global Satış (Milyon)")
plt.xlabel("Oyun Türleri")
plt.xticks(fontsize=9, rotation=40)
plt.show()

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
#Yoğunluk
sns.histplot(df.Platform, kde = False);   #distlot da olabilir
plt.xticks(fontsize = 0.1)
plt.show()

# %%
sns.scatterplot(x = "EU_Sales", y = "Global_Sales", data = df);

# %%
sns.scatterplot(x = "EU_Sales", y = "Global_Sales", hue = "Genre", data = df);

# %%
sns.lmplot( x = "JP_Sales", y = "NA_Sales", data = df);

# %%
sns.lmplot(x = "EU_Sales", y = "Global_Sales", hue = "Genre", data = df);

# %%
sns.pairplot(df);

# %%
sns.pairplot(df , hue = "Genre");
